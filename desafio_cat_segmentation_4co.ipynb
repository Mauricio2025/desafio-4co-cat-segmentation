# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AwyzRRuIedyipvBeevtA")
project = rf.workspace("mauricios-workspace-d613o").project("desafio-mariana-cat-seg")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 102.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 154.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Desafio-Mariana---Cat-Seg-2 in yolov11:: 100%|██████████| 212/212 [00:00<00:00, 7899.58it/s]

# %%
# 1. Instalar e Carregar a biblioteca
# !pip install ultralytics
from ultralytics import YOLO
from IPython.display import clear_output

clear_output() # Dá aquela limpada na tela

# 2. Carregar o cérebro zerado
modelo_oficial = YOLO("yolo11n-seg.pt")

# 3. O Treino MÁXIMO: 100 Épocas com 100 Imagens!
print("🚀 INICIANDO O TREINO FINAL DE 100 ÉPOCAS COM 100 IMAGENS...")
resultados = modelo_oficial.train(data=f"{dataset.location}/data.yaml", epochs=100, imgsz=640)
# Out:
# ...
# 🚀 INICIANDO O TREINO FINAL DE 100 ÉPOCAS COM 100 IMAGENS...
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import glob
from IPython.display import Image, display

# 1. Carrega o NOSSO CÉREBRO FINAL (a IA super treinada)
modelo_final = YOLO("runs/segment/train/weights/best.pt")

# 2. Pega as imagens ineditas de Validação
pasta_teste = f"{dataset.location}/valid/images/"

# 3. Faz a previsão com a confiança padrão de 25% (O desafio real!)
print("🔍 EXECUTANDO A IA NAS FOTOS INÉDITAS...")
resultado = modelo_final.predict(source=pasta_teste, save=True)

# 4. Pega a pasta com as fotos pintadas
pasta_resultado = sorted(glob.glob("runs/segment/predict*"))[-1]
todas_imagens = glob.glob(f"{pasta_resultado}/*.*")

# 5. Mostra as 3 primeiras vitórias na tela!
for img in todas_imagens[:3]:
    display(Image(filename=img))
    print("-" * 50)
# Out:
# 🔍 EXECUTANDO A IA NAS FOTOS INÉDITAS...
#
# image 1/20 /content/Desafio-Mariana---Cat-Seg-2/valid/images/andreia-oliveira-Q03Pmzl1dNU-unsplash_jpg.rf.9571897213c4f4598a8053018f21c418.jpg: 640x640 1 cat, 12.3ms
# image 2/20 /content/Desafio-Mariana---Cat-Seg-2/valid/images/anton-darius-GH_b1WXHKbU-unsplash_jpg.rf.cb7ea541d5b192ae25544dc932568a28.jpg: 640x640 2 cats, 13.2ms
# image 3/20 /content/Desafio-Mariana---Cat-Seg-2/valid/images/asique-alam-HaMYaR9J-Zg-unsplash_jpg.rf.0f9308ff50370e3f1c2d0019a09a7d9d.jpg: 640x640 2 cats, 9.9ms
# image 4/20 /content/Desafio-Mariana---Cat-Seg-2/valid/images/ayako-h7Dw2hF4e0A-unsplash_jpg.rf.86b15b3584e48e12cedf03355c060abb.jpg: 640x640 1 cat, 10.5ms
# image 5/20 /content/Desafio-Mariana---Cat-Seg-2/valid/images/engin-akyurt-usRA3jjRL4k-unsplash_jpg.rf.fbc9c9820ded5ecaa05bffc3ee944c30.jpg: 640x640 2 cats, 14.1ms
# ...

# %% [markdown]
# ---
# ## 🔮 BÔNUS: Prova de Conceito (PoC)
# **Mapeamento de Comportamento via Pose Estimation (Keypoints)**
#
# Antecipando a necessidade de traduzir expressões e movimentos corporais (ex: orelhas abaixadas, rabo abanando), a arquitetura abaixo demonstra o setup do modelo de **Pose Estimation**.
# O próximo passo para produtizar essa feature é substituir o modelo base por um treinado com um *Animal Pose Dataset* (mapeando de 17 a 20 pontos faciais/corporais dos pets).

# %%
# Instala a biblioteca caso o Colab tenha reiniciado
# !pip install ultralytics
from ultralytics import YOLO

# 1. Carrega o modelo de Estimativa de Pose (Esqueleto/Keypoints)
modelo_pose = YOLO('yolo11n-pose.pt')

# 2. Definição da fonte de teste (Vídeo ou Câmera em tempo real)
# source = "video_cachorro_correndo.mp4"

# 3. Inferência de Pose (Comentada para rodar apenas quando tivermos o dataset animal)
print("🚀 SETUP CONCLUÍDO: Pipeline de Pose Estimation pronto para receber o modelo treinado com Animal Keypoints.")
# resultados_pose = modelo_pose.predict(source=source, save=True, conf=0.5)

# A IA mapeará coordenadas X,Y de orelhas, olhos, patas e rabo.
# A variação matemática da distância entre esses pontos em (n) frames = Detecção de Comportamento.
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.5 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 🚀 SETUP CONCLUÍDO: Pipeline de Pose Estimation pronto para receber o modelo treinado com Animal Keypoints.

# %%
# ==========================================
# 1. COLE O SEU CÓDIGO DO ROBOFLOW AQUI EM CIMA!
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AwyzRRuIedyipvBeevtA")
project = rf.workspace("dataset-dcucb").project("dog-cat-pose-dfefd")
version = project.version(7)
dataset = version.download("yolov8")

# ==========================================

from ultralytics import YOLO
import glob
from IPython.display import Image, display

# 2. Carrega o modelo de POSE zerado
modelo_pose = YOLO('yolo11n-pose.pt')

# 3. Treino Expresso de 25 Épocas
print("🚀 TREINANDO A IA PARA LER LINGUAGEM CORPORAL (CÃES E GATOS)...")
resultados = modelo_pose.train(data=f"{dataset.location}/data.yaml", epochs=25, imgsz=640)

# 4. Pegando o modelo que acabou de ser treinado
modelo_pose_treinado = YOLO("runs/pose/train/weights/best.pt")

# 5. Forçando o teste em TODAS as fotos de validação para a gente escolher a do gato!
pasta_teste_pose = f"{dataset.location}/valid/images/"
print("🔍 TESTANDO NAS FOTOS...")
resultado_teste = modelo_pose_treinado.predict(source=pasta_teste_pose, save=True, conf=0.5)

# 6. Mostrando as 3 primeiras fotos pintadas com o esqueleto
pasta_resultado_pose = sorted(glob.glob("runs/pose/predict*"))[-1]
todas_imagens_pose = glob.glob(f"{pasta_resultado_pose}/*.*")

for img in todas_imagens_pose[:3]:
    display(Image(filename=img))
    print("-" * 50)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 76.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 132.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Dog-Cat-Pose-7 in yolov8:: 100%|██████████| 718/718 [00:00<00:00, 8944.89it/s]
# ...
